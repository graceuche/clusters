# %% [markdown]
# # K-Means Clustering Example
#
# [Cluster analysis or clustering](https://en.wikipedia.org/wiki/Cluster_analysis) is the task of grouping a set of objects in such a way that objects in the same group (called a cluster) are more similar (in some sense) to each other than to those in other groups (clusters).

# %% [markdown]
# Let's make some fake data that includes people clustered by income and age, randomly:

# %%
import numpy as np # imports numpy package

#Create fake income/age clusters
def create_clustered_data(num_people, clust): # creates a function create_clustered_data
    np.random.seed(10)
    points_per_cluster = num_people/clust # calculates the number of people per cluster
    clustered_data = [] # initializes clustered_data list
    for i in range (clust): # loops clust number of times e.g 5 or so 
        income_centroid = np.random.uniform(20000.0, 200000.0) # creates a random float between 20,000 - 200,000 
        age_centroid = np.random.uniform(20.0, 70.0) # creates a random float between 20-70 
        for j in range(int(points_per_cluster)): # loops as many times as we want people per cluster
            clustered_data.append([np.random.normal(income_centroid, 10000.0), np.random.normal(age_centroid, 2.0)]) # gets random number not far from the centroid of a cluster
    clustered_data = np.array(clustered_data) # converts list into numpy array
    return clustered_data # returns numpy array of clust number of clusters

# %% [markdown]
# ## 🏋️🏋️ In pairs or individually:
#
# 1. Comment every line in the function above or make some Markdown cells that explain the use of methods such as `np.random.uniform`
# 2. Uncomment and comment `np.random.seed(10)` and run the whole notebook to see what it does.

# %% [markdown]
# `np.random.seed()` makes random numbers predictable

# %% [markdown]
# We'll use k-means to rediscover these clusters in unsupervised learning:

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.preprocessing import scale
from numpy import random

data = create_clustered_data(100, 6)

model = KMeans(n_clusters=6)

# Note I'm scaling the data to normalize it! Important for good results.
model = model.fit(scale(data))

# We can look at the clusters each data point was assigned to
# print(model.labels_)

# And we'll visualize it:
plt.figure(figsize=(8, 6))
plt.scatter(data[:,0], data[:,1], c=model.labels_.astype(float))
plt.show()

# %% [markdown]
# ## 🏋️🏋️ In pairs or individually:
#
# - Make Markdown cells to answer questions:
#     - What happens if you do not scale the data?
#     - What happens if you choose different values of K?
# - Make more code cells that show 2,3,5,8, cluster. Explain clusters.
# - Try changing parameters to funcion `create_clustered_data` and cluster into different number of clusters
# - Experiment with markers and colors in charts

# %%
data = create_clustered_data(200, 2)

model = KMeans(n_clusters=2)

# Note I'm scaling the data to normalize it! Important for good results.
model = model.fit(scale(data))

# We can look at the clusters each data point was assigned to
# print(model.labels_)

# And we'll visualize it:
plt.figure(figsize=(8, 6))
plt.scatter(data[:,0], data[:,1], marker='D', c=model.labels_.astype(float), cmap='rainbow', alpha=0.7)
plt.show()

# %%
data = create_clustered_data(300, 4)

model = KMeans(n_clusters=4)

# Note I'm scaling the data to normalize it! Important for good results.
model = model.fit(scale(data))

# We can look at the clusters each data point was assigned to
# print(model.labels_)

# And we'll visualize it:
plt.figure(figsize=(8, 6))
plt.scatter(data[:,0], data[:,1], marker=">", c=model.labels_.astype(float), cmap='rainbow', alpha=0.7)
plt.show()

# %%
data = create_clustered_data(300, 6)

model = KMeans(n_clusters=6)

# Note I'm scaling the data to normalize it! Important for good results.
model = model.fit(scale(data))

# We can look at the clusters each data point was assigned to
# print(model.labels_)

# And we'll visualize it:
plt.figure(figsize=(8, 6))
plt.scatter(data[:,0], data[:,1], marker="p", c=model.labels_.astype(float), cmap='jet', alpha=0.7)
plt.show()

# %%
data = create_clustered_data(500, 8)

model = KMeans(n_clusters=8)

# Note I'm scaling the data to normalize it! Important for good results.
model = model.fit(scale(data))

# We can look at the clusters each data point was assigned to
# print(model.labels_)

# And we'll visualize it:
plt.figure(figsize=(8, 6))
plt.scatter(data[:,0], data[:,1], marker="1", c=model.labels_.astype(float), cmap='turbo', alpha=0.7)
plt.show();

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=d044cf07-d538-43cd-bcb9-2f324b04a29c' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
